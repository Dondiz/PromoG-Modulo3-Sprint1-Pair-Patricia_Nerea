# %%
import pandas as pd

# %%
df_p1 = pd.read_csv("files/world-data-2023_part1.csv", index_col= 0)
df_p1.columns
# Out:
# Index(['Country', 'Density\n(P/Km2)', 'Abbreviation', 'Agricultural Land( %)',
#        'Land Area(Km2)', 'Armed Forces size', 'Birth Rate', 'Calling Code',
#        'Capital/Major City', 'Co2-Emissions', 'CPI', 'CPI Change (%)',
#        'Currency-Code', 'Fertility Rate', 'Forested Area (%)',
#        'Gasoline Price'],
#       dtype='object')

# %%
df_p2 = pd.read_csv("files/world-data-2023_part2.csv", index_col= 0)
df_p2.columns
# Out:
# Index(['GDP', 'Gross primary education enrollment (%)',
#        'Gross tertiary education enrollment (%)', 'Infant mortality',
#        'Largest city', 'Life expectancy', 'Maternal mortality ratio',
#        'Minimum wage', 'Official language', 'Out of pocket health expenditure',
#        'Physicians per thousand', 'Population',
#        'Population: Labor force participation (%)', 'Tax revenue (%)',
#        'Total tax rate', 'Unemployment rate', 'Urban_population', 'country',
#        'coordinates'],
#       dtype='object')

# %%
df_final = df_p1.merge(df_p2, how = "inner", left_on = "Country", right_on= "country")
df_final
# Out:
#          Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0    Afghanistan               60           AF                58.10%
# 1        Albania              105           AL                43.10%
# 2        Algeria               18           DZ                17.40%
# 3        Andorra              164           AD                40.00%
# 4         Angola               26           AO                47.50%
# ..           ...              ...          ...                   ...
# 190    Venezuela               32           VE                24.50%
# 191      Vietnam              314           VN                39.30%
# 192        Yemen               56           YE                44.60%
# 193       Zambia               25           ZM                32.10%
# 194     Zimbabwe               38           ZW                41.90%
#
#     Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0          652,230           323,000       32.49          93.0
# ...

# %% [markdown]
# Después de la unión de datos, tenemos dos columnas de "country". Elimina una de ellas.

# %%
df_limpio = df_final.drop("country", axis = 1)

# %%
df_limpio
# Out:
#          Country Density\n(P/Km2) Abbreviation AgriculturalLand(%)  \
# 0    Afghanistan               60           AF              58.10%
# 1        Albania              105           AL              43.10%
# 2        Algeria               18           DZ              17.40%
# 3        Andorra              164           AD              40.00%
# 4         Angola               26           AO              47.50%
# ..           ...              ...          ...                 ...
# 190    Venezuela               32           VE              24.50%
# 191      Vietnam              314           VN              39.30%
# 192        Yemen               56           YE              44.60%
# 193       Zambia               25           ZM              32.10%
# 194     Zimbabwe               38           ZW              41.90%
#
#     LandArea(Km2) ArmedForcessize  BirthRate  CallingCode Capital/MajorCity  \
# 0         652,230         323,000      32.49         93.0             Kabul
# ...

# %% [markdown]
# Los nombres de las columnas no son homogeneos. Cambia los nombres de las columnas de tal forma que:
#
# No tengan espacios.
#
# Estén en minúscula.
#
# No tengan paréntesis, es decir, quitar "(%)", "(Km2)".
#
# Algunas columnas tiene "\n". Eliminalos de los nombres de las columnas.
#
# Algunas columnas tienen ":". Eliminalos de los nombres de las columnas.

# %%
df_espacios = df_limpio.columns.str.replace(" ", "")
df_limpio.columns = df_espacios

# %%
df_limpio
# Out:
#          Country Density\n(P/Km2) Abbreviation AgriculturalLand(%)  \
# 0    Afghanistan               60           AF              58.10%
# 1        Albania              105           AL              43.10%
# 2        Algeria               18           DZ              17.40%
# 3        Andorra              164           AD              40.00%
# 4         Angola               26           AO              47.50%
# ..           ...              ...          ...                 ...
# 190    Venezuela               32           VE              24.50%
# 191      Vietnam              314           VN              39.30%
# 192        Yemen               56           YE              44.60%
# 193       Zambia               25           ZM              32.10%
# 194     Zimbabwe               38           ZW              41.90%
#
#     LandArea(Km2) ArmedForcessize  BirthRate  CallingCode Capital/MajorCity  \
# 0         652,230         323,000      32.49         93.0             Kabul
# ...

# %%
columnas_sin_espacios = [col.replace(" ", "") for col in df_limpio.columns]
df_limpio.columns = columnas_sin_espacios

# %%
df_limpio["coordinates"]
# Out:
# 0        ('33.93911 ', '67.709953')
# 1       ('41.153332 ', '20.168331')
# 2        ('28.033886 ', '1.659626')
# 3        ('42.506285 ', '1.521801')
# 4      ('-11.202692 ', '17.873887')
#                    ...
# 190       ('6.42375 ', '-66.58973')
# 191    ('14.058324 ', '108.277199')
# 192     ('15.552727 ', '48.516388')
# 193    ('-13.133897 ', '27.849332')
# 194    ('-19.015438 ', '29.154857')
# Name: coordinates, Length: 195, dtype: object

# %%
df_limpio
# Out:
#          Country Density\n(P/Km2) Abbreviation AgriculturalLand(%)  \
# 0    Afghanistan               60           AF              58.10%
# 1        Albania              105           AL              43.10%
# 2        Algeria               18           DZ              17.40%
# 3        Andorra              164           AD              40.00%
# 4         Angola               26           AO              47.50%
# ..           ...              ...          ...                 ...
# 190    Venezuela               32           VE              24.50%
# 191      Vietnam              314           VN              39.30%
# 192        Yemen               56           YE              44.60%
# 193       Zambia               25           ZM              32.10%
# 194     Zimbabwe               38           ZW              41.90%
#
#     LandArea(Km2) ArmedForcessize  BirthRate  CallingCode Capital/MajorCity  \
# 0         652,230         323,000      32.49         93.0             Kabul
# ...

# %%
df_minusculas = df_espacios.str.lower()
df_limpio.columns = df_minusculas

# %%
df_limpio
# Out:
#          country density\n(p/km2) abbreviation agriculturalland(%)  \
# 0    Afghanistan               60           AF              58.10%
# 1        Albania              105           AL              43.10%
# 2        Algeria               18           DZ              17.40%
# 3        Andorra              164           AD              40.00%
# 4         Angola               26           AO              47.50%
# ..           ...              ...          ...                 ...
# 190    Venezuela               32           VE              24.50%
# 191      Vietnam              314           VN              39.30%
# 192        Yemen               56           YE              44.60%
# 193       Zambia               25           ZM              32.10%
# 194     Zimbabwe               38           ZW              41.90%
#
#     landarea(km2) armedforcessize  birthrate  callingcode capital/majorcity  \
# 0         652,230         323,000      32.49         93.0             Kabul
# ...

# %%
df_parentesis = df_minusculas.str.replace("\([^)]*\)", "", regex=True)
df_limpio.columns = df_parentesis

# %%
df_salto = df_parentesis.str.replace("\n", "")
df_limpio.columns = df_salto

# %%
df_corregido = df_salto.str.replace(":", "")
df_limpio.columns = df_corregido

# %% [markdown]
# La columnas coordinates tiene la latitud y la longitud en una sola columna. Crea dos columnas nuevas, una con la longitud y otra con la latitud. Una vez hecho, elimina la columna de coordinates.

# %%
df_limpio[['latitude', 'longitude']] = df_limpio['coordinates'].str.split(',', expand=True)

# %%
df_limpio['coordinates'].str.split(',', expand=True)
# Out:
#                   0               1
# 0      ('33.93911 '    '67.709953')
# 1     ('41.153332 '    '20.168331')
# 2     ('28.033886 '     '1.659626')
# 3     ('42.506285 '     '1.521801')
# 4    ('-11.202692 '    '17.873887')
# ..              ...             ...
# 190     ('6.42375 '    '-66.58973')
# 191   ('14.058324 '   '108.277199')
# 192   ('15.552727 '    '48.516388')
# 193  ('-13.133897 '    '27.849332')
# 194  ('-19.015438 '    '29.154857')
#
# [195 rows x 2 columns]

# %%
#df_coordinates= df_limpio.columns.str.replace(r'\(', '', regex=True)  .str.replace(r'\)', '', regex=True)
#df_limpio.columns = df_coordinates

# %%
df_limpio.drop("coordinates", axis=1)
# Out:
#          country density abbreviation agriculturalland   landarea  \
# 0    Afghanistan      60           AF           58.10%    652,230
# 1        Albania     105           AL           43.10%     28,748
# 2        Algeria      18           DZ           17.40%  2,381,741
# 3        Andorra     164           AD           40.00%        468
# 4         Angola      26           AO           47.50%  1,246,700
# ..           ...     ...          ...              ...        ...
# 190    Venezuela      32           VE           24.50%    912,050
# 191      Vietnam     314           VN           39.30%    331,210
# 192        Yemen      56           YE           44.60%    527,968
# 193       Zambia      25           ZM           32.10%    752,618
# 194     Zimbabwe      38           ZW           41.90%    390,757
#
#     armedforcessize  birthrate  callingcode capital/majorcity co2-emissions  \
# 0           323,000      32.49         93.0             Kabul         8,672
# ...

# %% [markdown]
# Las columnas unemployment_rate, total_tax_rate, tax_revenue, population_labor_force_participation, out_of_pocket_health_expenditure, gross_tertiary_education_enrollment, gross_primary_education_enrollment, forested_area, cpi_change, agricultural_land tienen "%". Elimina los "%" de los valores de las columnas.

# %%
columnas= [
    "unemploymentrate",
    "totaltaxrate",
    "taxrevenue",
    "populationlaborforceparticipation",
    "outofpockethealthexpenditure",
    "grosstertiaryeducationenrollment",
    "grossprimaryeducationenrollment",
    "forestedarea",
    "cpichange",
    "agriculturalland",
]

# %%
for columna in columnas:
    df_limpio[columna] = df_limpio[columna].str.replace("%", "")

# %%
df_limpio
# Out:
#          country density abbreviation agriculturalland   landarea  \
# 0    Afghanistan      60           AF            58.10    652,230
# 1        Albania     105           AL            43.10     28,748
# 2        Algeria      18           DZ            17.40  2,381,741
# 3        Andorra     164           AD            40.00        468
# 4         Angola      26           AO            47.50  1,246,700
# ..           ...     ...          ...              ...        ...
# 190    Venezuela      32           VE            24.50    912,050
# 191      Vietnam     314           VN            39.30    331,210
# 192        Yemen      56           YE            44.60    527,968
# 193       Zambia      25           ZM            32.10    752,618
# 194     Zimbabwe      38           ZW            41.90    390,757
#
#     armedforcessize  birthrate  callingcode capital/majorcity co2-emissions  \
# 0           323,000      32.49         93.0             Kabul         8,672
# ...

# %%
df_limpio.columns
# Out:
# Index(['country', 'density', 'abbreviation', 'agriculturalland', 'landarea',
#        'armedforcessize', 'birthrate', 'callingcode', 'capital/majorcity',
#        'co2-emissions', 'cpi', 'cpichange', 'currency-code', 'fertilityrate',
#        'forestedarea', 'gasolineprice', 'gdp',
#        'grossprimaryeducationenrollment', 'grosstertiaryeducationenrollment',
#        'infantmortality', 'largestcity', 'lifeexpectancy',
#        'maternalmortalityratio', 'minimumwage', 'officiallanguage',
#        'outofpockethealthexpenditure', 'physiciansperthousand', 'population',
#        'populationlaborforceparticipation', 'taxrevenue', 'totaltaxrate',
#        'unemploymentrate', 'urban_population', 'coordinates', 'latitude',
#        'longitude'],
#       dtype='object')

# %%
columnas2 = ["gasolineprice", "gdp", "minimumwage"]

# %%
for columna in columnas2:
    df_limpio[columna] = df_limpio[columna].str.replace("$", "", regex=True)

# %%
df_limpio
# Out:
#          country density abbreviation agriculturalland   landarea  \
# 0    Afghanistan      60           AF            58.10    652,230
# 1        Albania     105           AL            43.10     28,748
# 2        Algeria      18           DZ            17.40  2,381,741
# 3        Andorra     164           AD            40.00        468
# 4         Angola      26           AO            47.50  1,246,700
# ..           ...     ...          ...              ...        ...
# 190    Venezuela      32           VE            24.50    912,050
# 191      Vietnam     314           VN            39.30    331,210
# 192        Yemen      56           YE            44.60    527,968
# 193       Zambia      25           ZM            32.10    752,618
# 194     Zimbabwe      38           ZW            41.90    390,757
#
#     armedforcessize  birthrate  callingcode capital/majorcity co2-emissions  \
# 0           323,000      32.49         93.0             Kabul         8,672
# ...
